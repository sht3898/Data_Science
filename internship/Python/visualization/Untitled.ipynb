# %%
import requests
import bs4

endpoint = 'http://apis.data.go.kr/6300000/tourFoodDataService/tourFoodDataListJson?'
serviceKey = '4WL3rpgrWA3KqnYYeAHcpD%2B6w4QgYF6By2xloUCumceSaddda5Wkam2h%2B%2BD8CrJuICJD309Bymhp7i%2Bd9a37yw%3D%3D'
pageNo = '1'
numOfRows = '1000'

paramset = 'serviceKey=' + serviceKey + '&pageNo=' + pageNo + '&numOfRows=' + numOfRows

url = endpoint + paramset

# %%
result = requests.get(url).json()

# %%
result['msgBody']
# Out:
# [{'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '151',
#   'foodSeq': 'FH0000934',
#   'name': '관리자테스트',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'telCode': '123',
#   'telKuk': '1234',
#   'telNo': '1234'},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '150',
#   'foodSeq': 'FH0000933',
#   'name': '신토불이',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'telCode': '042',
#   'telKuk': '242',
#   'telNo': '3555'},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '134',
#   'foodSeq': 'FH0000918',
#   'name': '챠오챠오',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '짜장면',
#   'telCode': '042',
#   'telKuk': '526',
#   'telNo': '9295',
#   'contents1': ' 대전시 서구 갈마2동에 위치한 중국음식 전문점이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '133',
#   'foodSeq': 'FH0000917',
#   'name': '만다린',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '자연송이전복',
#   'telCode': '042',
#   'telKuk': '489',
#   'telNo': '2060',
#   'contents1': '서구 둔산동에 위치하고 있는 정통중국요리 전문점이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '132',
#   'foodSeq': 'FH0000914',
#   'name': '삼국지',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '송이전복',
#   'telCode': '042',
#   'telKuk': '482',
#   'telNo': '7855',
#   'contents1': ' 서구 만년동에 위치하고 있는 중식 레스토랑이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '127',
#   'foodSeq': 'FH0000913',
#   'name': '천년의 정원',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '전가복',
#   'telCode': '042',
#   'telKuk': '485',
#   'telNo': '1796',
#   'contents1': ' 대전시 서구 만년동에 위치하고 있는 중식 레스토랑이다.'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '124',
#   'foodSeq': 'FH0000912',
#   'name': '산골묵집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '도토리묵, 보리밥',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '9900',
#   'contents1': ' 묵집으로 유명한 관평동에 위치하고 있다.\r\n'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '123',
#   'foodSeq': 'FH0000911',
#   'name': '산밑할머니',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '도토리묵, 보리밥',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '7922',
#   'contents1': ' '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '122',
#   'foodSeq': 'FH0000910',
#   'name': '솔밭묵집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '도토리묵',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '5686',
#   'contents1': '  대전시 유성구 관평동에 위치한 솔밭묵집이다.'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '126',
#   'foodSeq': 'FH0000909',
#   'name': '구즉 이서방 묵집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '도토리묵',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '1517',
#   'contents1': ' 대전에는 묵집으로 유명한 집이 많다. 이곳도 그중의 한 집인데 묵 뿐만 아니라 토종닭도 전문으로 하는 곳이다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '125',
#   'foodSeq': 'FH0000908',
#   'name': '원조50년 구즉할머니 묵집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '도토리묵',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '5842',
#   'contents1': '  이곳은 유성구 봉산동에 위치한 묵집이다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '121',
#   'foodSeq': 'FH0000907',
#   'name': '구즉묵집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '묵밥',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '2016',
#   'contents1': '  대전시 유성구 송강동에 위치한 이곳은 묵밥으로 유명한 곳이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '양식',
#   'idx': '120',
#   'foodSeq': 'FH0000906',
#   'name': '친친',
#   'dCode': 'C0303',
#   'dGu': 'C0603',
#   'topMenu': '파스타',
#   'telCode': '042',
#   'telKuk': '488',
#   'telNo': '7776',
#   'contents1': '  서구 만년동에 위치한 이탈리아식 레스토랑이다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '119',
#   'foodSeq': 'FH0000905',
#   'name': '무지개한정식',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '한정식',
#   'telCode': '042',
#   'telKuk': '224',
#   'telNo': '3030',
#   'contents1': '  중구 대흥동에 위치한 중국 레스토랑이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '118',
#   'foodSeq': 'FH0000904',
#   'name': '차이나 공',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '매생이, 해물누룽지탕',
#   'telCode': '042',
#   'telKuk': '486',
#   'telNo': '6613',
#   'contents1': ' 대전시 서구 만년동에 위치한 중국 레스토랑이다.'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '중식',
#   'idx': '131',
#   'foodSeq': 'FH0000903',
#   'name': '라오왕 전민점',
#   'dCode': 'C0302',
#   'dGu': 'C0604',
#   'topMenu': '전가복',
#   'telCode': '042',
#   'telKuk': '867',
#   'telNo': '1688',
#   'contents1': ' 이곳은 중국 정통요리의 참 맛을 느낄 수 있는 곳이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '117',
#   'foodSeq': 'FH0000902',
#   'name': '천안문',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '전가복',
#   'telCode': '042',
#   'telKuk': '488',
#   'telNo': '3150',
#   'contents1': '대전시 서구 둔산동에 위치한 천안문은 전통 중국 레스토랑이다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '양식',
#   'idx': '130',
#   'foodSeq': 'FH0000901',
#   'name': '아웃백 스테이크하우스',
#   'dCode': 'C0303',
#   'dGu': 'C0605',
#   'topMenu': '갈릭 립아이',
#   'telCode': '042',
#   'telKuk': '253',
#   'telNo': '0671',
#   'contents1': ' 패밀리 레스토랑 중에서도 아웃백 스테이크 하우스는 꽤 유명하다. 그중에서 대전 은행점의 아웃백은 친절한 서비스와 봉사정신으로 으뜸으로 꼽힌다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '양식',
#   'idx': '129',
#   'foodSeq': 'FH0000900',
#   'name': '베니건스',
#   'dCode': 'C0303',
#   'dGu': 'C0603',
#   'topMenu': '텍사스립아이스테이크',
#   'telCode': '042',
#   'telKuk': '488',
#   'telNo': '6100',
#   'contents1': ' 패밀리 레스토랑인 베니건스를 모르는 사람은 아마도 없을 것이다. 그중에서 대전 둔산점의 베니건스는 이용한 고객들의 추천이 끊이질 않는 곳이다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '114',
#   'foodSeq': 'FH0000183',
#   'name': '진로집',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '두부두루치기',
#   'telCode': '042',
#   'telKuk': '226',
#   'telNo': '0914',
#   'contents1': ' ‘두부두루치기’의 원조 진로집. 사장님의 친정 어머니때부터 시작되어 2대째 운영하고 있다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '113',
#   'foodSeq': 'FH0000180',
#   'name': '내집식당',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '올갱이국',
#   'telCode': '042',
#   'telKuk': '223',
#   'telNo': '5083',
#   'contents1': '이 집은 충북 옥천 맑은 물에서 잡아 올린 푸른색을 띄는 올갱이만을 사용한다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '116',
#   'foodSeq': 'FH0000179',
#   'name': '영동식당',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '닭도리탕',
#   'telCode': '042',
#   'telKuk': '531',
#   'telNo': '6016',
#   'contents1': '연중무휴인 이 식당은 18평 남짓 크지 않은 가게이지만 변하지 않는 맛으로 30년 전통을 이어오고 있다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '중식',
#   'idx': '112',
#   'foodSeq': 'FH0000178',
#   'name': '희락반점',
#   'dCode': 'C0302',
#   'dGu': 'C0605',
#   'topMenu': '양장피',
#   'telCode': '042',
#   'telKuk': '256',
#   'telNo': '0273',
#   'contents1': '30년 이상의 전통을 가지고 있는 이곳은 대전에서 유명하다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '115',
#   'foodSeq': 'FH0000177',
#   'name': '신촌설렁탕',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '설렁탕',
#   'telCode': '042',
#   'telKuk': '254',
#   'telNo': '6350',
#   'contents1': '대전에는 설렁탕으로 유명한 집이 많은데 이곳도 그중의 하나이다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '111',
#   'foodSeq': 'FH0000175',
#   'name': '느티나무집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '설렁탕',
#   'telCode': '042',
#   'telKuk': '822',
#   'telNo': '1212',
#   'contents1': '88년부터 우리 농산물만을 고집하여 전통을 이어온 식당이 있다. 오랫동안 고아낸 깊은 육수의 맛이 일품인 설렁탕을 맛보면 이곳의 단골이 되지 않을 수 없다. '},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '110',
#   'foodSeq': 'FH0000174',
#   'name': '금성삼계탕',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '삼계탕',
#   'telCode': '042',
#   'telKuk': '254',
#   'telNo': '3422',
#   'contents1': ' 1980년에 개업하여 20년이 넘게 성업중인 금성삼계탕. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '103',
#   'foodSeq': 'FH0000129',
#   'name': '오는정',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '이북식 손만두국',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '7915',
#   'contents1': ' 이북식 손만두국 전문점인 오는정. 이곳에서는 서리태를 직접 갈아서 바로 만드는 시원한 콩국수, 소치맛살 양지육수와 직접 빚은 이북식 만두가 잘 어우러진 진한 손만두국이 유명하다. 생녹두를 갈아서 무와 배추를 넣은 깔끔하고 아삭한 녹두전 또한 일품이다. 연중무휴로 운영하여 공휴일에 찾아오더라도 식사 할수 있고, 메뉴는 포장도 가능하다. 이외에도 직접 끓인 갈비탕 평양냉면, 해물파전, 돼지두루치기, 소불고기전골과 꿩전골, 토끼탕 등 다양한 메뉴가 있다. 평범한 만두에 질렸다면 이곳에서 이북식의 만두를 먹어보자. \r\n'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '88',
#   'foodSeq': 'FH0000096',
#   'name': '대나무통밥 큰정식',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '대나무통밥',
#   'telCode': '042',
#   'telKuk': '632',
#   'telNo': '3399',
#   'contents1': ' 대전 대덕구에 위치한 이 음식점은 이름 그대로 ‘대나무통밥’ 하면 가장 맛있는 집으로 이름이 알려져 있다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '109',
#   'foodSeq': 'FH0000095',
#   'name': '청양골',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '생등심',
#   'telCode': '042',
#   'telKuk': '823',
#   'telNo': '8977',
#   'contents1': '한우암소 생고기 전문점인 청양골은  1, 2층 200평이 넘는 넓은 규모의 음식점으로, 픽업 서비스까지 두루 갖춘 모범 음식점이다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '87',
#   'foodSeq': 'FH0000094',
#   'name': '청주해장국',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '등뼈해장국',
#   'telCode': '042',
#   'telKuk': '822',
#   'telNo': '0050',
#   'contents1': '청결, 맛, 신속, 미소’가 사훈인 청주해장국은, 70년 전통을 이어오는 손맛 그대로를 자랑한다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '86',
#   'foodSeq': 'FH0000093',
#   'name': '만나유성점',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '샤브샤브, 한정식',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '2001',
#   'contents1': ' ‘만나’는 구약성경 ‘출애굽기’에서 이스라엘 백성들이 40년여 동안 광야에서 생활할 때 주식으로 먹었던 ‘하늘의 양식’을 가리키는 말에서 유래했다. 외식산업의 발전을 선도하고 믿음과 사랑을 바탕으로 고객을 모신다는 신념 아래 가장 좋은 재료를 엄선하여 모든 음식을 만들어내는 데 전 직원이 주력하고 있다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '85',
#   'foodSeq': 'FH0000092',
#   'name': '모정',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '한정식 코스',
#   'telCode': '042',
#   'telKuk': '824',
#   'telNo': '3377',
#   'contents1': ' 전통한정식으로 유명한 ‘모정’은 그 이름만큼이나 어머니의 정성을 그대로 담은 손맛 가득한 음식이 제공된다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '102',
#   'foodSeq': 'FH0000091',
#   'name': '서울가든',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '돼지갈비',
#   'telCode': '\u3000',
#   'telKuk': '\u3000',
#   'telNo': '\u3000',
#   'contents1': '  미식가라면 누구나 한 번쯤 들른다는 서울가든은 1981년 9월부터 시작하여 꾸준히 높은 인기를 유지하고 있는 전통 있는 음식점이다. ‘'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '일식',
#   'idx': '69',
#   'foodSeq': 'FH0000090',
#   'name': '미락가',
#   'dCode': 'C0304',
#   'dGu': 'C0604',
#   'topMenu': '미락가 스페셜 생선회',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '5548',
#   'contents1': '매일 매일, 대전과 남해안 산지에서 직접 잡아 올린 신선한 해물을 가져와 그 자리에서 요리하는 것으로 잘 알려진 미락가는, 생생하게 살아 숨쉬는 해산물을 맛보고 싶어 하는 사람이라면 누구나 한번쯤 들르는 곳이다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '68',
#   'foodSeq': 'FH0000089',
#   'name': '서라벌',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '한정식',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '0400',
#   'contents1': '  깔끔하고 편안하면서도 탁 트인 홀, 가족들과 모처럼의 외식 혹은 중요한 사람들의 접대나 주요한 행사를 치르기 위한 곳을 찾고 있다면 이곳을 추천할 만하다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '101',
#   'foodSeq': 'FH0000088',
#   'name': '강남복집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '복지리탕',
#   'telCode': '\u3000',
#   'telKuk': '\u3000',
#   'telNo': '\u3000',
#   'contents1': ' 여수에서 주3회로 신선한 어류를 직접 받아서 만드는 복지리탕은 강남복집의 최고 메뉴다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '일식',
#   'idx': '108',
#   'foodSeq': 'FH0000087',
#   'name': '우미일식',
#   'dCode': 'C0304',
#   'dGu': 'C0604',
#   'topMenu': '우미정식',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '5501',
#   'contents1': '  38년 경력의 일식전문가의 남다른 손맛으로 만들어지는 우미일식의 요리들은 한 번 맛을 보면 그 맛을 잊을 수 없다.'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '양식',
#   'idx': '107',
#   'foodSeq': 'FH0000086',
#   'name': '로제타',
#   'dCode': 'C0303',
#   'dGu': 'C0604',
#   'topMenu': '콤보정식',
#   'telCode': '042',
#   'telKuk': '862',
#   'telNo': '3332',
#   'contents1': ' 감미로운 음악, 진한 커피향이 분위기를 돋아주는 패밀리 레스토랑 로제타. 주말이나 저녁 데이트를 즐기는 연인과, 외식을 즐기는 가족들로 붐비는 이곳은, 대전 유성구 엑스포 과학공원 감천변에 위치하여 창밖으로 보이는 감천의 여유를 느낄 수 있는 최상의 장소다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '66',
#   'foodSeq': 'FH0000084',
#   'name': '논두렁 추어칼국수',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '추어칼국수',
#   'telCode': '042',
#   'telKuk': '272',
#   'telNo': '7589',
#   'contents1': ' 정읍 고창에서 주1회로 직접 잡아온 생생한 국내산 미꾸라지를 사용해서 만든 추어칼국수는, 추어 육수를 걸러서 국물을 만들기 때문에 한번 맛을 본 사람은 그 맛을 잊을 수 없다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '100',
#   'foodSeq': 'FH0000083',
#   'name': '제주뜰 향 갈치전문점',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '갈치조림',
#   'telCode': '042',
#   'telKuk': '254',
#   'telNo': '5155',
#   'contents1': ' 총 100석, 70평의 탁 트인 홀을 자랑하는 제주뜰향 갈치 전문점은, 어린이를 동행한 가족모임, 회식, 생일파티, 접대 등으로 안성맞춤이다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '84',
#   'foodSeq': 'FH0000082',
#   'name': '광천식당',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '두부두루치기',
#   'telCode': '042',
#   'telKuk': '226',
#   'telNo': '4751',
#   'contents1': '  30년 전통의 식당이다. 신선한 재료와 한결같은 손맛이 자랑인 이집의 인기메뉴는 두부두루치기이다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '99',
#   'foodSeq': 'FH0000081',
#   'name': '초량',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '황태정식',
#   'telCode': '042',
#   'telKuk': '255',
#   'telNo': '4563',
#   'contents1': '   ‘집에서 먹는 밥보다 더 정성스럽게 만든다’라는 생각으로 모든 음식을 만드는 초량식당은, 20년 전통으로 이미 그 맛이 널리 알려져 있다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '65',
#   'foodSeq': 'FH0000080',
#   'name': '감나무식당',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '오리한방백숙',
#   'telCode': '042',
#   'telKuk': '931',
#   'telNo': '1114',
#   'contents1': '  단체예약손님들이 끊이지 않을 정도로 그 맛으로 유명한 이곳은 오리한방백숙, 닭볶음탕, 백숙, 오리표고버섯 요리가 주 메뉴다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '기타',
#   'idx': '98',
#   'foodSeq': 'FH0000079',
#   'name': '대청매실가든',
#   'dCode': 'C0305',
#   'dGu': 'C0601',
#   'topMenu': '오리, 닭백숙',
#   'telCode': '042',
#   'telKuk': '931',
#   'telNo': '3838',
#   'contents1': '매실농장을 함께 운영하고 있는 대청매실촌돼지는 모든 음식에 조미료 대신 매실원액으로 그 맛을 내는 것으로 유명하다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '64',
#   'foodSeq': 'FH0000078',
#   'name': '만남가든',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '닭도리탕',
#   'telCode': '042',
#   'telKuk': '934',
#   'telNo': '5518',
#   'contents1': '  닭도리탕과 토끼탕이 주 메뉴인 만남가든은 대청댐 입구에 자리 잡은 아담한 음식점이다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '양식',
#   'idx': '83',
#   'foodSeq': 'FH0000077',
#   'name': '뿌리가 나무에게',
#   'dCode': 'C0303',
#   'dGu': 'C0601',
#   'topMenu': '런치',
#   'telCode': '042',
#   'telKuk': '934',
#   'telNo': '7252',
#   'contents1': '  대청댐의 흐르는 강물을 보면서 맛있는 식사와 차를 즐길 수 있는 이곳은, 런치메뉴와 치즈 스파게티로 유명하다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '양식',
#   'idx': '63',
#   'foodSeq': 'FH0000076',
#   'name': '베네베네',
#   'dCode': 'C0303',
#   'dGu': 'C0601',
#   'topMenu': '안심 스테이크',
#   'telCode': '042',
#   'telKuk': '933',
#   'telNo': '0520',
#   'contents1': ' 최고 쉐프의 명품 양식 요리를 맛보고 싶다면 이곳을 추천한다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '106',
#   'foodSeq': 'FH0000075',
#   'name': '역발산',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '장뇌삼 삼계탕',
#   'telCode': '042',
#   'telKuk': '933',
#   'telNo': '0521',
#   'contents1': '  ‘장뇌삼’으로 만든 각종 메뉴들은 그 어디에서도 맛볼 수 없었던 이색적인 음식을 선사한다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '97',
#   'foodSeq': 'FH0000074',
#   'name': '통나무가든',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '간장게장',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '5267',
#   'contents1': ' 꽃게장을 좋아하지만 입맛이 까다로워 적절한 곳을 찾지 못했다면 단연 이곳을 추천한다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '중식',
#   'idx': '96',
#   'foodSeq': 'FH0000073',
#   'name': '꽁뚜',
#   'dCode': 'C0302',
#   'dGu': 'C0601',
#   'topMenu': '북경오리',
#   'telCode': '042',
#   'telKuk': '483',
#   'telNo': '9999',
#   'contents1': ' 포루투갈어로 ‘이야기’라는 뜻의 꽁뚜는 ‘맛있는 이야기’라는 의미를 담은 세련된 레스토랑이다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '62',
#   'foodSeq': 'FH0000072',
#   'name': '예산 소갈비',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '한우양념갈비',
#   'telCode': '042',
#   'telKuk': '636',
#   'telNo': '9292',
#   'contents1': ' 먼 곳에서도 이름을 듣고 찾아온다는 예산 소갈비는, 전통 명품 한우로 그 이름이 알려져 있다. 60년 전통을 자랑하는 이곳은 한우 양념갈비를 좋아하지 않는 사람이라도 금세 그 맛에 반할 만큼 맛이 일품이라고 한다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '105',
#   'foodSeq': 'FH0000071',
#   'name': '만수산 칡냉면',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '칡냉면',
#   'telCode': '042',
#   'telKuk': '623',
#   'telNo': '3500',
#   'contents1': ' 대덕구 중리동에 위치한 이곳은 칡냉면뿐 아니라, 비빔냉면과 함께 점심특선으로 소불고기, 묵은지등갈비찜이 인기 만점이다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '기타',
#   'idx': '95',
#   'foodSeq': 'FH0000070',
#   'name': '대청마루 추어칼국수',
#   'dCode': 'C0305',
#   'dGu': 'C0601',
#   'topMenu': '추어칼국수',
#   'telCode': '042',
#   'telKuk': '632',
#   'telNo': '7640',
#   'contents1': '  질 좋은 미꾸라지만을 고집하는 이곳은 국물이 담백하고 진한 추어 칼국수 맛이 일품이다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '94',
#   'foodSeq': 'FH0000069',
#   'name': '임청농장',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '오리, 닭백숙',
#   'telCode': '042',
#   'telKuk': '932',
#   'telNo': '6586',
#   'contents1': ' 닭, 오리 전문점인 임청농장에서는 주인이 직접 정성 들여 키운 닭으로 요리를 선보인다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '93',
#   'foodSeq': 'FH0000068',
#   'name': '한밭수산활어회센타',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '활어회',
#   'telCode': '042',
#   'telKuk': '622',
#   'telNo': '0777',
#   'contents1': ' 18년 전통을 자랑하며 대전시의 활어회를 대표 할 정도로 오래된 역사가 있는 이곳은 음식점을 찾아주는 손님들에게 시원한 활어회를 선사한다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '61',
#   'foodSeq': 'FH0000067',
#   'name': '혜성옥 설렁탕',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '설렁탕',
#   'telCode': '042',
#   'telKuk': '673',
#   'telNo': '4895',
#   'contents1': ' 대전에는 설렁탕이 유명한 집이 꽤 많다. 대덕구 중리동에 위치한 혜성옥은 대전의 설렁탕 맛집으로 손꼽힌다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '92',
#   'foodSeq': 'FH0000066',
#   'name': '유가옥설렁탕',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '설렁탕',
#   'telCode': '042',
#   'telKuk': '626',
#   'telNo': '3450',
#   'contents1': '10년 전통의 설렁탕 전문점인 유가옥 설렁탕. 24시간 연중 무휴로 운영하기 때문에 언제든지 배고프면 찾아오기 너무 좋은 곳이다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '91',
#   'foodSeq': 'FH0000065',
#   'name': '솔지원',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '샤브샤브',
#   'telCode': '042',
#   'telKuk': '624',
#   'telNo': '9255',
#   'contents1': ' 환경사랑 모범음식점으로 지정된 솔지원은 10년의 전통이 있는 곳이다. '},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '60',
#   'foodSeq': 'FH0000064',
#   'name': '맑은골 호박꼬지',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '호박꼬지찌개',
#   'telCode': '042',
#   'telKuk': '626',
#   'telNo': '4045',
#   'contents1': '옛날 전통방식의 토종호박을 이용한 향토음식으로 유명한 곳이다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '59',
#   'foodSeq': 'FH0000063',
#   'name': '나루터식당',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '장어구이',
#   'telCode': '042',
#   'telKuk': '932',
#   'telNo': '2404',
#   'contents1': ' 31년 전통의 이집은 매우 유명하다. 각종 TV프로그램에 방영되서 상을 수상하고, 대전시장 표창, 보건복지부장관 표창, 대전한밭음식축제 최우수상, 내무부장관 표창 등등.. 상이란 상은 모두 받은 듯 수상한 경력이 화려하다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '58',
#   'foodSeq': 'FH0000062',
#   'name': '전원가든',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '빠가 매운탕',
#   'telCode': '042',
#   'telKuk': '932',
#   'telNo': '1229',
#   'contents1': '  이곳은 전원의 향이 가득한 곳이다. 매운탕의 맛이 일품이며 그중에서도 얼큰한 빠가매운탕이 유명하다. 이외에도 쏘가리 매운탕, 메기 매운탕 등이 푸짐하게 제공된다.'},
#  {'dGuNm': '대덕구',
#   'dCodeNm': '한식',
#   'idx': '57',
#   'foodSeq': 'FH0000061',
#   'name': '구구전복 삼계탕',
#   'dCode': 'C0301',
#   'dGu': 'C0601',
#   'topMenu': '전복삼계탕',
#   'telCode': '042',
#   'telKuk': '623',
#   'telNo': '9952',
#   'contents1': '  전복과 삼계탕의 절묘한 만남! ‘전복 삼계탕’. 몸에 좋다는 전복과 삼계탕의 만남이 사람들의 입맛을 사로잡고 있다. 조리방법이 공식화되어 있고 신탄진 음식축제에도 출품했다고 한다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '82',
#   'foodSeq': 'FH0000060',
#   'name': '왕관식당',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '콩나물밥, 육회',
#   'telCode': '042',
#   'telKuk': '221',
#   'telNo': '1663',
#   'contents1': '  이집에 방문하려면 서두르는 것이 좋겠다. 하루 2시간(12:00~14:00)만 영업하기 때문이다. 식당에 들어서면 구수한 콩나물 냄새가 반기는 콩나물밥 전문점이다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '56',
#   'foodSeq': 'FH0000058',
#   'name': '모다드렁',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '조랑말육회',
#   'telCode': '042',
#   'telKuk': '223',
#   'telNo': '5092',
#   'contents1': '  제주도 산지에서 주 2회 직접 공수한다. 대전에서 유일하게 신선한 양질의 조랑말 육회맛을 맛볼 수 있는 곳이다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '중식',
#   'idx': '55',
#   'foodSeq': 'FH0000057',
#   'name': '복록수',
#   'dCode': 'C0302',
#   'dGu': 'C0605',
#   'topMenu': '깐쇼새우',
#   'telCode': '042',
#   'telKuk': '551',
#   'telNo': '4441',
#   'contents1': '  14년 전통의 중국집. 중국인이 직접 요리하여 중국 전통의 요리 맛을 느낄 수 있다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '53',
#   'foodSeq': 'FH0000055',
#   'name': '신토불이',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '추어탕',
#   'telCode': '042',
#   'telKuk': '252',
#   'telNo': '3555',
#   'contents1': '  추어탕의 효능이야 말로 하면 입아프다. 전국 맛집을 다니면서 노하우를 쌓았다고 하니 음식맛도 말로 하면 입아프다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '104',
#   'foodSeq': 'FH0000054',
#   'name': '나룻터식당',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '콩나물탕',
#   'telCode': '042',
#   'telKuk': '253',
#   'telNo': '5386',
#   'contents1': '  20년 전통의 콩나물탕으로 유명한 나룻터식당. 푸짐한 콩나물, 북어, 바지락에 매운 청양고추, 마늘을 넣어 끓인 국물은 시원한 맛을 한층 더해준다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '일식',
#   'idx': '81',
#   'foodSeq': 'FH0000053',
#   'name': '유천동 문창회집',
#   'dCode': 'C0304',
#   'dGu': 'C0605',
#   'topMenu': ' ',
#   'telCode': '042',
#   'telKuk': '525',
#   'telNo': '5810',
#   'contents1': ' '},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '52',
#   'foodSeq': 'FH0000052',
#   'name': '장수두부촌',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '두부버섯전골',
#   'telCode': '042',
#   'telKuk': '586',
#   'telNo': '5989',
#   'contents1': '  일반 장어구이, 두부 집이 아니다. 친환경 농산물을 사용하며, 그날 그날 사용할 만큼만 만들어 제공하는 1등급 콩의 무공해 두부! 남성 건강의 활력과 여성 피부 미용의 탄력에 좋은 최선의 선택~'},
#  {'dGuNm': '중구',
#   'dCodeNm': '기타',
#   'idx': '80',
#   'foodSeq': 'FH0000051',
#   'name': '통안골 가든',
#   'dCode': 'C0305',
#   'dGu': 'C0605',
#   'topMenu': '흑염소 전골, 구이,수육, 탕',
#   'telCode': '042',
#   'telKuk': '222',
#   'telNo': '6655',
#   'contents1': '  남녀노소 누구에게나 좋은 건강식품 ‘흑염소’! 중구 대흥동 통안골 가든에 오면 유기농 토종오가피로 달인 흑염소 보양식을 즐길 수 있다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '79',
#   'foodSeq': 'FH0000050',
#   'name': '귀빈회관',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '돌솥밥',
#   'telCode': '042',
#   'telKuk': '242',
#   'telNo': '3355',
#   'contents1': '  27년간 한결같은 맛과 최선을 다하고자 하는 정성이 느껴지는 귀빈돌솥밥. 지역농산물을 사용하는 웰빙식당이다. '},
#  {'dGuNm': '중구',
#   'dCodeNm': '기타',
#   'idx': '78',
#   'foodSeq': 'FH0000049',
#   'name': '플라잉팬',
#   'dCode': 'C0305',
#   'dGu': 'C0605',
#   'topMenu': '피자 까르보나라',
#   'telCode': '042',
#   'telKuk': '223',
#   'telNo': '3004',
#   'contents1': '  분위기 좋은 레스토랑에서의 여유로운 식사, 외국인과 함께하기 좋은 깔끔하고 격식있는 만남, 해외여행 때 맛보았던 돌가마로 구운 씬피자, 유럽의 노천 카페에서 마셨던 커피, 이 모든 것을 즐길수 있는 곳이 바로 플라잉팬이다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '기타',
#   'idx': '51',
#   'foodSeq': 'FH0000048',
#   'name': '참홍탁',
#   'dCode': 'C0305',
#   'dGu': 'C0605',
#   'topMenu': '흑산도 홍탁삼합',
#   'telCode': '042',
#   'telKuk': '222',
#   'telNo': '9928',
#   'contents1': '  VJ특공대, 한식탐험대 등 각종 맛집에 소개되어 그 맛을 인정받은 홍탁! 2009년 Best 이노베이션 기업 & 브랜드 맛의 명가 부문수상의 경력을 가지고 있는 홍탁요리 전문점이다.'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '41',
#   'foodSeq': 'FH0000047',
#   'name': '경회루',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '한정식',
#   'telCode': '\u3000',
#   'telKuk': '\u3000',
#   'telNo': '\u3000',
#   'contents1': '  전통 한국요리 최고의 진수를 보여준다는 경회루이다. 14년 전통의 한식요리를 선보여 왔다는 이곳의 대표메뉴는 국정식이다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '일식',
#   'idx': '40',
#   'foodSeq': 'FH0000046',
#   'name': '어수사',
#   'dCode': 'C0304',
#   'dGu': 'C0604',
#   'topMenu': '회정식',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '4949',
#   'contents1': '  봉명동 445-3번지에는 어수사일식집이 있다. 어디서 들어본 이름이라 했는데 어수선일식의 분점이라고 한다. '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '일식',
#   'idx': '89',
#   'foodSeq': 'FH0000045',
#   'name': '어수선',
#   'dCode': 'C0304',
#   'dGu': 'C0604',
#   'topMenu': ' ',
#   'telCode': '042',
#   'telKuk': '825',
#   'telNo': '6699',
#   'contents1': '  기본에 충실한 어수선일식, 이름부터 재미있는 듯하다. 20년 경력의 주방장이 최고급 재료로 하나하나 정성을 다하여 만드는 일식집이다.  '},
#  {'dGuNm': '유성구',
#   'dCodeNm': '기타',
#   'idx': '39',
#   'foodSeq': 'FH0000044',
#   'name': '숯골 원 냉면',
#   'dCode': 'C0305',
#   'dGu': 'C0604',
#   'topMenu': '물냉면,비빔냉면',
#   'telCode': '042',
#   'telKuk': '861',
#   'telNo': '3287',
#   'contents1': '  1955년부터 시작하여 55년 전통의 3대 가업을 이은 숯골원냉면! 신선하고 쫄깃한 토종닭 백숙과 새콤달콤한 동치미 국물로 육수를 낸 구수한 메밀냉면이 이집의 자랑거리이다.'},
#  {'dGuNm': '유성구',
#   'dCodeNm': '한식',
#   'idx': '38',
#   'foodSeq': 'FH0000043',
#   'name': '원조솔밭묵집',
#   'dCode': 'C0301',
#   'dGu': 'C0604',
#   'topMenu': '채묵',
#   'telCode': '042',
#   'telKuk': '935',
#   'telNo': '5686',
#   'contents1': '  솔향이 가득한 이집에는 소박한 냄새가 난다. 칼로리가 낮고 알칼리 음식이라 건강에도 좋은 묵으로 만든 채묵이 별미이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '50',
#   'foodSeq': 'FH0000042',
#   'name': '킹덤',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '뷔페',
#   'telCode': '042',
#   'telKuk': '483',
#   'telNo': '0072',
#   'contents1': '  뷔페식 패밀리 레스토랑 킹덤! 웅장하고 다이나믹한 분위기의 도심속에 자리잡은 새로운 개념의 즉석뷔페이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '49',
#   'foodSeq': 'FH0000041',
#   'name': '청해수산',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '모듬회',
#   'telCode': '042',
#   'telKuk': '483',
#   'telNo': '0283',
#   'contents1': '  딱 들어서면 넓은 내부에 놀라고, 많은 사람들에 또 한번 놀란다. 킹덤뷔페와 같은 건물에 있다. 대전에서 이곳을 모르면 간첩이라는 말이 있을 정도로 유명한 건물임에 틀림이 없다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '37',
#   'foodSeq': 'FH0000040',
#   'name': '한마음면옥',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '냉면',
#   'telCode': '042',
#   'telKuk': '536',
#   'telNo': '0408',
#   'contents1': '  직접 담근 동치미 육수와 사태, 전골을 푹 우려낸 사골육수를 배합하여 그 맛이 담백하다. 감자와 고구마 전분을 배합한 면발이 쫄깃쫄깃하고 살아있는 듯 하여 매니아들이 자주 찾는 전통 냉면의 한마음 면옥이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '77',
#   'foodSeq': 'FH0000039',
#   'name': '태원',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '삼선팔보채',
#   'telCode': '042',
#   'telKuk': '488',
#   'telNo': '8838',
#   'contents1': '  지하 1층, 지상 3층 규모의 10년의 전통을 이어온 중식당이 있다. 가족모임이나 연회, 회식자리나 접대 등에 좋은 이곳은 저렴하면서도 TV추천 맛집으로도 유명하다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '48',
#   'foodSeq': 'FH0000038',
#   'name': '무지개회관',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '돌솥밥',
#   'telCode': '042',
#   'telKuk': '488',
#   'telNo': '5600',
#   'contents1': '  10년의 노하우로 인정받고 있는 맛있는 음식점이 여기 있다. 뜨끈한 돌솥밥에 곁들여지는 20여가지의 나물과 야채들은 인공재배가 아니라 시골 할머니들이 직접 채취한 자연산 나물을 맛볼 수 있다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '36',
#   'foodSeq': 'FH0000037',
#   'name': '우리집 삼식이',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '삼식이 회무침',
#   'telCode': '042',
#   'telKuk': '483',
#   'telNo': '8889',
#   'contents1': '  쫀득쫀득 새콤한 삼식이회무침과 매운탕을 맛볼 수 있는 곳으로, 회무침 접시를 둘러싼 생 깻잎에 싸서 먹는다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '일식',
#   'idx': '35',
#   'foodSeq': 'FH0000036',
#   'name': '온누리',
#   'dCode': 'C0304',
#   'dGu': 'C0603',
#   'topMenu': '활어회',
#   'telCode': '042',
#   'telKuk': '472',
#   'telNo': '8242',
#   'contents1': '  대전 서구 둔산동에 위치한 온누리수산은 20년 전통의 대전 대표 음식점이다. 2007년 이집의 1대주가 국무총리 표창을 받은데 이어 2대주인 장남이 대를 이어 운영해 나가고 있다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '76',
#   'foodSeq': 'FH0000035',
#   'name': '팔도청국장',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '청국장',
#   'telCode': '042',
#   'telKuk': '472',
#   'telNo': '0073',
#   'contents1': '  넓고 깨끗한 인테리어가 돋보이는 청국장 전문점이다. 청국장 하면 그 냄새가 문제라면 문제인데, 이곳은 냄새없는 청국장으로 많은 사람들에게 인기있는 집이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '일식',
#   'idx': '34',
#   'foodSeq': 'FH0000034',
#   'name': '지중해',
#   'dCode': 'C0304',
#   'dGu': 'C0603',
#   'topMenu': '참치생선회',
#   'telCode': '042',
#   'telKuk': '471',
#   'telNo': '8188',
#   'contents1': '  깔끔한 품격있는 인테리어가 돋보이는 이곳은 참치생선회를 즐길 수 있는 곳이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '47',
#   'foodSeq': 'FH0000033',
#   'name': '평양면옥',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '불고기',
#   'telCode': '042',
#   'telKuk': '485',
#   'telNo': '4848',
#   'contents1': '  320평 대규모의 평양면옥. 굉장히 넓고 쾌적한 실내에 깔끔한 인테리어가 돋보이는 곳이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '중식',
#   'idx': '33',
#   'foodSeq': 'FH0000032',
#   'name': '자유대반점',
#   'dCode': 'C0302',
#   'dGu': 'C0603',
#   'topMenu': '전가복',
#   'telCode': '042',
#   'telKuk': '472',
#   'telNo': '5605',
#   'contents1': '  40년 전통의 2대째 내려오고 있는 중국요리 전문점이 있다. 120평의 넓은 공간에 200대 주차가 가능한 시설을 갖추고 있는 자유대 반점은 상견례 자리나 회식, 접대에 적합한 장소이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '75',
#   'foodSeq': 'FH0000031',
#   'name': '영동그릴',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '흑염소전골',
#   'telCode': '042',
#   'telKuk': '369',
#   'telNo': '0050',
#   'contents1': '  국내 유일 흑염소 요리로 대통령께 진상하였던 바로 그 솜씨와 맛을 바로 이곳에서 맛볼 수 있다고 한다. 각방송국 TV와 전국적인 신문과 잡지에 소개되었다고 하니 과연 그 유명세가 대단하다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '32',
#   'foodSeq': 'FH0000030',
#   'name': '왕춘식당',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '돌솥한정식',
#   'telCode': '042',
#   'telKuk': '471',
#   'telNo': '0035',
#   'contents1': '  160평의 넓직한 공간에 50여대의 주차공간을 갖춘 왕춘식당. 이집은 돌솥한정식으로 유명하다. 고슬고슬한 밥과 23~4가지 되는 푸짐한 반찬이 제공된다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '46',
#   'foodSeq': 'FH0000029',
#   'name': '외갓집 식당',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '두부보쌈버섯전골',
#   'telCode': '042',
#   'telKuk': '486',
#   'telNo': '7447',
#   'contents1': '  이름만으로도 어머니의 손맛이 느껴질 것 같은 외갓집 식당의 대표메뉴는 ‘두부보쌈’과 ‘버섯전골’이다. 매일 직접 만든 손두부와 한방수육으로 담백하고 쫄깃한 맛이 일품인 두부보쌈과, 고기를 넣지 않은 담백한 맛으로 시원하고 깔끔한 맛이 나는 버섯전골은 이 식당의 효도 메뉴이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '74',
#   'foodSeq': 'FH0000028',
#   'name': '5.5 닭갈비',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '닭갈비',
#   'telCode': '042',
#   'telKuk': '486',
#   'telNo': '2315',
#   'contents1': '  맛<별 5> 최고, 만족<별 5> 최고 라는 뜻의 5.5닭갈비는 매콤달콤하게 요리한 닭갈비 집이다. 이곳에서는 고춧가루와 마늘 즙, 양파 즙 등 19가지 신선한 재료를 배합하여 저온 숙성한 소스를 사용한다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '31',
#   'foodSeq': 'FH0000027',
#   'name': '두울 샤브 칼국수',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '샤브샤브 칼국수',
#   'telCode': '042',
#   'telKuk': '472',
#   'telNo': '0250',
#   'contents1': ' 신선한 야채와 고기가 어우러진 웰빙음식으로 손꼽히는 남녀노소 누구나 좋아하는 샤브샤브. 최상품의 신선한 식자재를 직접 구입하는 것은 물론, 지속적인 직원교육을 통하여 맛과 품질, 양, 크기, 분위기와 서비스까지 모두 만족할 수 있도록 최선을 다한다. 샤브샤브 칼국수를 1인에 5천원에서 1만3천원에 먹을 수 있다. 야채, 고기, 해물이 함께 어우러진 웰빙샤브를 먹은 후에 그 진한 국물에 끓여먹는 칼국수 또한 일품이다. 칼국수를 건져 먹고 나면 그 국물에 밥을 볶아 먹는데 아무리 배가 불러도 꼭 먹어야 할 정도 맛있다. 어린이 놀이방도 운영하고 있어 아이들과 함께 오기에 매우 좋겠다.\r\n'},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '45',
#   'foodSeq': 'FH0000026',
#   'name': '황태칼국수',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '황태칼국수',
#   'telCode': '042',
#   'telKuk': '581',
#   'telNo': '2580',
#   'contents1': '  들어서는 순간 우리집에 온것만 같은 편안한 느낌이 난다는 황태칼국수집. 11년의 전통을 이어오는 집이라서 그런걸까. 진부령황태만을 사용한다는 이집은 모든 음식에 황태, 다시마, 무 등을 5시간 이상 가마솥에 끓여서 만든 황태국물을 사용하여 진한 국물 맛이 일품이다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '30',
#   'foodSeq': 'FH0000025',
#   'name': '우가촌',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '간장게장',
#   'telCode': '042',
#   'telKuk': '471',
#   'telNo': '0069',
#   'contents1': '  화려하지도 않으며 그렇다고 대단하게 모양을 내지도 않았다. 가정집 안방에서 흔히보는 상차림이다. 그러나 항상 손님들로 북적이는 것을 보면 무언가 특별한 맛이 있는 곳임에 틀림이 없다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '73',
#   'foodSeq': 'FH0000024',
#   'name': '등대 민물 매운탕',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '빠가탕',
#   'telCode': '042',
#   'telKuk': '486',
#   'telNo': '5413',
#   'contents1': '  국내산 메기, 쏘가리, 빠가사리로 얼큰한 매운탕을 맛보고 싶다면 이곳 등대민물매운탕 집으로 와보자. 식당이란 음식의 맛도 중요하지만 친절과 서비스 또한 매우 중요한데 이곳은 두가지를 모두 갖추고 있다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '29',
#   'foodSeq': 'FH0000023',
#   'name': '전통콩나물밥',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '콩나물밥',
#   'telCode': '042',
#   'telKuk': '483',
#   'telNo': '8898',
#   'contents1': '웰빙시대에 영양만점 건강음식 콩나물밥으로 입맛이 없을 때 별다른 반찬 없이 콩나물과 양념장만으로도 맛있게 식사할 수 있는 곳이다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '28',
#   'foodSeq': 'FH0000022',
#   'name': '설악 칡 냉면',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '칡냉면',
#   'telCode': '042',
#   'telKuk': '489',
#   'telNo': '5252',
#   'contents1': ' 대전의 간판 냉면집인 설악 칡냉면! 칡은 혈관계 질환의 예방에 좋으며 고혈압, 동맥경화, 고지혈증에도 효과가 알려져 있다. 피로회복과 숙취해소, 위장과 간장을 보호해 주며 체내의 중금속도 배출시켜 주는 효능이 있다고 하니 여름철 보양식이 따로 없다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '44',
#   'foodSeq': 'FH0000021',
#   'name': '암소만한우가',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '암소만 한정식',
#   'telCode': '042',
#   'telKuk': '476',
#   'telNo': '3700',
#   'contents1': '  이곳은 개업한지 1년 남짓 된 식당이다. 하지만 그 맛과 품질은 벌써 소문이 나서 많은 사람들이 찾아오는 맛집으로 자리매김 하였다. '},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '26',
#   'foodSeq': 'FH0000019',
#   'name': '구봉농장',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '멧돼지 숯불구이',
#   'telCode': '042',
#   'telKuk': '545',
#   'telNo': '3000',
#   'contents1': '  구봉산 중간지점에 위치한 30년 전통의 멧돼지구이 전문점이다. 돼지고기의 맛을 순수하고 전달하고 싶어 한가지 분야만을 고집한다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '기타',
#   'idx': '25',
#   'foodSeq': 'FH0000018',
#   'name': '토종칼국수',
#   'dCode': 'C0305',
#   'dGu': 'C0603',
#   'topMenu': '칼국수',
#   'telCode': '042',
#   'telKuk': '545',
#   'telNo': '5662',
#   'contents1': '대전시 서구 가수원동에 위치한 토종칼국수. 고향의 맛으로 승부하는 토종칼국수를 3천5백원의 저렴한 가격에 맛볼 수 있다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '24',
#   'foodSeq': 'FH0000017',
#   'name': '금평식당',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '추어탕',
#   'telCode': '042',
#   'telKuk': '583',
#   'telNo': '6866',
#   'contents1': '  30년 전통의 금평식당은 매니아 층이 많다. 아들이 본점을 운영하고 막내딸이 분점을 운영하고 있다 한다. 직접 재배한 친환경 야채로만 요리한다고 하니 그 정성을 알만하다.'},
#  {'dGuNm': '중구',
#   'dCodeNm': '한식',
#   'idx': '72',
#   'foodSeq': 'FH0000016',
#   'name': '사리원면옥',
#   'dCode': 'C0301',
#   'dGu': 'C0605',
#   'topMenu': '냉면',
#   'telCode': '042',
#   'telKuk': '256',
#   'telNo': '6506',
#   'contents1': '  3대째 60년의 전통을 이어오고 있는 평양식 냉면집이 있다. 소고기로 만든 깊고 그윽한 육수와 메밀면으로 면발이 부드럽고 구수하다.'},
#  {'dGuNm': '서구',
#   'dCodeNm': '한식',
#   'idx': '23',
#   'foodSeq': 'FH0000015',
#   'name': '부뚜막 두부 마을',
#   'dCode': 'C0301',
#   'dGu': 'C0603',
#   'topMenu': '순두부',
#   'telCode': '042',
#   'telKuk': '537',
#   'telNo': '8884',
#   'contents1': '  시골에서 재배한 국산콩으로 만든 부뚜막 두부마을. 신선하고 담백한 손 두부의 맛을 볼 수 있으며 새로 개발한 검은콩두부는 건강식품으로도 손색이 없는 좋은 식품이다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '43',
#   'foodSeq': 'FH0000014',
#   'name': '한밭식당',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '설렁탕',
#   'telCode': '042',
#   'telKuk': '256',
#   'telNo': '1565',
#   'contents1': '  대전에서 음식점 1호로 통한다는 한밭식당에는 많은 유명인사들도 방문할 정도로 이름이 나 있다. 손수 담은 겉저리 깍두기는 그 맛에서, 또 정성에서 전국적으로 유명하며 또 음식에는 조미료를 사용하지 않아 재료 고유의 깔끔하고 담백한 맛을 느낄 수 있다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '기타',
#   'idx': '71',
#   'foodSeq': 'FH0000013',
#   'name': '두울 샤브 칼국수',
#   'dCode': 'C0305',
#   'dGu': 'C0602',
#   'topMenu': '상추쌈샤브',
#   'telCode': '042',
#   'telKuk': '253',
#   'telNo': '1011',
#   'contents1': '  남녀노소 누구나 좋아하는 샤브샤브. 신선한 야채와 고기가 어우러진 웰빙음식으로 손꼽힌다. 최상품의 신선한 식자재를 직접 구입하고, 지속적인 직원교육을 통하여 맛과 품질, 양, 크기, 분위기와 서비스까지 모두 만족할 수 있도록 최선을 다한다는 것이 이집의 신념이다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '중식',
#   'idx': '22',
#   'foodSeq': 'FH0000012',
#   'name': '태화장',
#   'dCode': 'C0302',
#   'dGu': 'C0602',
#   'topMenu': '왕새우 채리',
#   'telCode': '042',
#   'telKuk': '256',
#   'telNo': '2407',
#   'contents1': '  태화장은 대전 시내에서 내력이 가장 오래된 중국집으로, 대전의 중국요리를 대중음식으로 자리매김한 효시집이나 다름없다. 6.25직후 문을열어 50년 전통의 중국요리의 맛을 그대로 선보이는 곳이다. '},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '21',
#   'foodSeq': 'FH0000011',
#   'name': '만인산 식당',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '상추쌈 샤브샤브',
#   'telCode': '042',
#   'telKuk': '274',
#   'telNo': '0700',
#   'contents1': '대전광역시와 충남 금산군의 경계에 자리 잡고 있는 만인산 식당. 만인산에 위치하고 있어 산책이나 등산등으로 지친 심신을 달래줄 휴식공간같은 식당이다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '20',
#   'foodSeq': 'FH0000010',
#   'name': '산내별천지',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '한방토종백숙',
#   'telCode': '042',
#   'telKuk': '271',
#   'telNo': '0207',
#   'contents1': '30년 전통의 이곳은 정말 별천지이다. 정원과 연못이 잘 어우러진 경관과 물레방아는 향수를 느끼게 해주는 듯 하다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '19',
#   'foodSeq': 'FH0000009',
#   'name': '동서회관',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '장어구이',
#   'telCode': '042',
#   'telKuk': '284',
#   'telNo': '5825',
#   'contents1': '  18년의 전통을 가진 동서회관은 주인인 송명범씨가 모든 음식을 직접 굽고 만드는 것으로 유명하다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '70',
#   'foodSeq': 'FH0000008',
#   'name': '고구려 명장',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '삼계탕',
#   'telCode': '042',
#   'telKuk': '627',
#   'telNo': '8229',
#   'contents1': '  삼계탕은 만인이 좋아하는 보양식이다. 이집의 삼계탕은 한그릇 한그릇이 보약한첩과 같다. 그만큼 각종 약재와 함께 정성으로 만들었기 때문이다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '18',
#   'foodSeq': 'FH0000007',
#   'name': '용운산성',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '생갈비',
#   'telCode': '042',
#   'telKuk': '285',
#   'telNo': '6692',
#   'contents1': '  이집은 생등심, 생갈비, 갈비살, 양념갈비, 불고기 등 다양하지만, 어떤 메뉴를 선택해도 후회가 없을 정도로 신선하고 육질이 좋은 고기가 항상 손님상에 오른다. '},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '17',
#   'foodSeq': 'FH0000006',
#   'name': '강변한우',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '한우구이',
#   'telCode': '042',
#   'telKuk': '274',
#   'telNo': '5633',
#   'contents1': '  1등급 이상의 한우 암소만을 사용한 요리는 강변한우만의 자랑거리다. 보기만 해도 군침이 도는 한우구이에, 유기농으로 직접 재배한 각종 채소, 게다가 전통 재래 방식으로 손수 띄운 구수한 청국장은 최고의 조화를 이룬다. '},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '42',
#   'foodSeq': 'FH0000005',
#   'name': '참마음청주 감자탕.해장국',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': '감자탕',
#   'telCode': '042',
#   'telKuk': '628',
#   'telNo': '8824',
#   'contents1': '  뼛속 깊이 우려낸 시원하면서도 담백한 감자탕을 맛보고 싶다면 청주 감자탕 해장국을 먹어보자. 대전 동구에 위치한 청구 감자탕 해장국집은, 온 가족 외식 장소로 그만이다.'},
#  {'dGuNm': '동구',
#   'dCodeNm': '한식',
#   'idx': '16',
#   'foodSeq': 'FH0000004',
#   'name': '황간 올갱이 전문점',
#   'dCode': 'C0301',
#   'dGu': 'C0602',
#   'topMenu': ' ',
#   'telCode': '042',
#   'telKuk': '623',
#   'telNo': '0120',
#   'contents1': '  각종 야채와 단백질이 많이 함유된 올갱이로 국물을 우려낸 시원한 올갱이국을 먹고 싶다면, 도심속의 숲속 황간 올갱이 전문점을 찾아가보자.'}]
